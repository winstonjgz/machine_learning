# %% [markdown]
# # Fundamento teorico
#
# **Regresion simple**
#
# $$y= \beta_0 + \beta_1 x$$
#
#
# **Regresion multiple**
# $$y= \beta_0 + \beta_1 x_1 + \beta_2 x_2 $$

# %% [markdown]
# **REGRESIÓN LINEAL SIMPLE**

# %%
#Importacion ded librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Establecer ruta de acceso en dr
import os
print(os.getcwd())
os.chdir("/content/gdrive/MyDrive/Carpeta compartida")
# Out:
# Mounted at /content/gdrive
# /content

# %%
#Importacion de los datos
dataset = pd.read_csv("student_scores.csv", sep = ",")

# %%
#Vemos el dataset
dataset
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
#Shape
dataset.shape
# Out:
# (25, 2)

# %%
#Ploteamos el dataset
dataset.plot(x='Hours', y='Scores', style="o")
plt.title('Hours vs Percentage')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Score')
plt.show()

# %%
#1) Preparacion de datos
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

# %%
# 3) Entrenando el modelo
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
#Recuperamos la intersección
print(regressor.intercept_)
# Out:
# 2.48367340537321

# %%
#La pendiente
print(regressor.coef_)
# Out:
# [9.77580339]

# %% [markdown]
# ## Ahora con una red Neurona

# %%
import numpy as np

# Clase de la red neuronal simple
class SimpleNeuralNetwork:
    def __init__(self):
        # Inicializar peso y sesgo aleatoriamente
        self.w = np.random.rand()
        self.b = np.random.rand()

    def forward(self, x):
        # Calcular la salida
        return self.w * x + self.b

    def train(self, X, y_true, learning_rate=0.01, epochs=1000):
        # Entrenamiento de la red neuronal
        for epoch in range(epochs):
            # Predicción
            y_pred = self.forward(X)

            # Cálculo de la pérdida (error cuadrático medio)
            loss = np.mean((y_pred - y_true) ** 2)

            # Cálculo de los gradientes
            dw = (2 / len(X)) * np.dot(X, (y_pred - y_true))  # Derivada respecto a w
            db = (2 / len(X)) * np.sum(y_pred - y_true)      # Derivada respecto a b

            # Actualización de los parámetros
            self.w -= learning_rate * dw
            self.b -= learning_rate * db

            # Opcional: imprimir la pérdida cada 100 épocas
            if epoch % 100 == 0:
                print(f'Época {epoch}: Pérdida = {loss}, w = {self.w}, b = {self.b}')

# Datos de ejemplo
X = dataset['Hours'].values
y_true = dataset['Scores'].values

# Inicializar la red neuronal
nn = SimpleNeuralNetwork()

# Entrenar la red neuronal
nn.train(X, y_true)

# Resultados finales
print(f"\nDespués del entrenamiento: Peso (w) = {nn.w}, Sesgo (b) = {nn.b}")
# Out:
# Época 0: Pérdida = 2781.963491171708, w = 6.561607783281314, b = 1.51672324392554
# Época 100: Pérdida = 28.90025095807857, w = 9.823884443769883, b = 2.1858028717546665
# Época 200: Pérdida = 28.89088014156293, w = 9.80859557644224, b = 2.280520079195482
# Época 300: Pérdida = 28.88652130864465, w = 9.798168280350314, b = 2.3451190024394584
# Época 400: Pérdida = 28.884493798621616, w = 9.791056667602382, b = 2.3891766873842855
# Época 500: Pérdida = 28.88355070285019, w = 9.78620641347795, b = 2.4192248600971116
# Época 600: Pérdida = 28.883112022092046, w = 9.782898448617459, b = 2.4397182810408253
# Época 700: Pérdida = 28.882907969848993, w = 9.780642354145396, b = 2.4536951809338756
# Época 800: Pérdida = 28.882813055000053, w = 9.779103655132092, b = 2.463227690472273
# Época 900: Pérdida = 28.882768905382207, w = 9.778054233362367, b = 2.4697290419017692
#
# Después del entrenamiento: Peso (w) = 9.777344394025304, Sesgo (b) = 2.4741266207607757

# %%
#Recuperamos la intersección
print(regressor.intercept_)
# Out:
# 2.48367340537321

# %%
print(regressor.coef_)
# Out:
# [9.77580339]
